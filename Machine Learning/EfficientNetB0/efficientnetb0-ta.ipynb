# %%
import os
import random
import shutil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import Model
from tensorflow.keras.utils import img_to_array, load_img
from shutil import copyfile
from PIL import Image
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.95 and logs.get('val_accuracy')>=0.94):
      self.model.stop_training = True

callbacks = myCallback()

# %%
# Resized gambar agar memiliku jumlah pixel yang sama
def copy_to_working(path, new_path):
  for filename in os.scandir(path):
#     img = Image.open(os.path.join(path, filename.name))
#     img_resized= img.resize(new_size)
#     img_resized.save(os.path.join(new_path, filename.name))
    copyfile(os.path.join(path, filename.name), os.path.join(new_path, filename.name))

# %%
# Membuat direktori untuk menempatka data yang akan digunakan

resized_dir = '/kaggle/working/Resized_Dataset'
source_dir = '/kaggle/input/coffee-leaf-diseases'

if os.path.exists(resized_dir):
  shutil.rmtree(resized_dir)

def create_train_test_dirs(resized_path):
  os.mkdir(resized_path)
  os.mkdir(os.path.join(resized_path, 'train'))
  os.mkdir(os.path.join(resized_path, 'test'))

  for foldername in os.listdir(os.path.join(source_dir, 'train')):
    for i in os.listdir(resized_path):
      os.mkdir(os.path.join(resized_path, i, foldername))

try:
  create_train_test_dirs(resized_path=resized_dir)
except FileExistsError:
  print("File Sudah Ada")

# %%
# Train Source
train_miner_source = os.path.join(source_dir, 'train/miner/')
train_healthy_source = os.path.join(source_dir, 'train/nodisease/')
train_phoma_source = os.path.join(source_dir, 'train/phoma/')
train_rust_source = os.path.join(source_dir, 'train/rust/')

# Test Source
test_miner_source = os.path.join(source_dir, 'test/miner/')
test_healthy_source = os.path.join(source_dir, 'test/nodisease/')
test_phoma_source = os.path.join(source_dir, 'test/phoma/')
test_rust_source = os.path.join(source_dir, 'test/rust/')

# Train Resized
train_miner_resized = os.path.join(resized_dir, 'train/miner/')
train_healthy_resized = os.path.join(resized_dir, 'train/nodisease/')
train_phoma_resized = os.path.join(resized_dir, 'train/phoma/')
train_rust_resized = os.path.join(resized_dir, 'train/rust/')

# Test Resized
test_miner_resized = os.path.join(resized_dir, 'test/miner/')
test_healthy_resized = os.path.join(resized_dir, 'test/nodisease/')
test_phoma_resized = os.path.join(resized_dir, 'test/phoma/')
test_rust_resized = os.path.join(resized_dir, 'test/rust/')

# %%
# Melihat contoh ukuran dataset
sample_image  = load_img('/kaggle/input/coffee-leaf-diseases/train/phoma/16.jpg')
sample_array = img_to_array(sample_image)
print(f"Each image has shape: {sample_array.shape}")

sample_image  = load_img('/kaggle/input/coffee-leaf-diseases/test/phoma/500.jpg')
sample_array = img_to_array(sample_image)
print(f"Each image has shape: {sample_array.shape}")
# Out:
# Each image has shape: (1024, 2048, 3)
# Each image has shape: (1024, 2048, 3)

# %%
# train_source_list = [train_miner_source, train_healthy_source, train_phoma_source, train_rust_source]
# test_source_list = [test_miner_source, test_healthy_source, test_phoma_source, test_rust_source]
# train_resized_list = [train_miner_resized, train_healthy_resized, train_phoma_resized, train_rust_resized]
# test_resized_list = [test_miner_resized, test_healthy_resized, test_phoma_resized, test_rust_resized]

# for train in train_source_list:
#     for resized in train_resized_list:
#         if train_source_list.index(train) == train_resized_list.index(resized):
#           copy_to_working(train, resized)
        
# for test in test_source_list:
#     for resized in test_resized_list:
#         if test_source_list.index(test) == test_resized_list.index(resized):
#           copy_to_working(test, resized)

# %%
# # Jumlah gambar yang ingin tersisa di setiap folder
# train_jumlah_tersisa = 280
# test_jumlah_tersisa = 60

# for folder in train_resized_list:
#     # Dapatkan daftar semua file gambar dalam folder
#     gambar = [file for file in os.listdir(folder) if file.endswith(('.jpg', '.jpeg', '.png', '.gif'))]

#     # Pastikan jumlah gambar yang ingin tersisa tidak melebihi jumlah gambar yang ada
#     jumlah_tersisa = min(train_jumlah_tersisa, len(gambar))

#     # Jumlah gambar yang akan dihapus
#     jumlah_hapus = len(gambar) - train_jumlah_tersisa

#     # Acak urutan gambar
#     random.shuffle(gambar)

#     # Hapus gambar secara acak sampai tersisa jumlah tertentu
#     for i in range(jumlah_hapus):
#         file = os.path.join(folder, gambar[i])
#         os.remove(file)
        
# for folder in test_resized_list:
#     # Dapatkan daftar semua file gambar dalam folder
#     gambar = [file for file in os.listdir(folder) if file.endswith(('.jpg', '.jpeg', '.png', '.gif'))]

#     # Pastikan jumlah gambar yang ingin tersisa tidak melebihi jumlah gambar yang ada
#     jumlah_tersisa = min(test_jumlah_tersisa, len(gambar))

#     # Jumlah gambar yang akan dihapus
#     jumlah_hapus = len(gambar) - test_jumlah_tersisa

#     # Acak urutan gambar
#     random.shuffle(gambar)

#     # Hapus gambar secara acak sampai tersisa jumlah tertentu
#     for i in range(jumlah_hapus):
#         file = os.path.join(folder, gambar[i])
#         os.remove(file)

# print('Penghapusan selesai.')

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Tentukan path folder train dan test
train_dir = '/kaggle/input/coffee-leaf-diseases/train'
test_dir = '/kaggle/input/coffee-leaf-diseases/test'
# train_dir = '/kaggle/working/Resized_Dataset/train'
# test_dir = '/kaggle/working/Resized_Dataset/test'

# Tentukan dimensi gambar yang diharapkan
input_shape = (224, 224)

# Load dataset train menjadi array numpy
train_images = []
train_labels = []
val_images = []
val_labels = []
classes = ['miner', 'nodisease', 'phoma', 'rust']
for class_index, class_name in enumerate(classes):
    class_dir = os.path.join(train_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
#         image = tf.keras.preprocessing.image.load_img(image_path, target_size=input_shape)
#         image_array = tf.keras.preprocessing.image.img_to_array(image)
        img = Image.open(image_path).convert('RGB')
        img = img.resize((300, 300 * img.size[1] // img.size[0]), Image.Resampling.LANCZOS)
        inp_numpy = np.array(img)[None]
        image_array = tf.constant(inp_numpy, dtype='float32')
        train_images.append(image_array)
        train_labels.append(class_index)
    class_dir = os.path.join(test_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
#         image = tf.keras.preprocessing.image.load_img(image_path, target_size=input_shape)
#         image_array = tf.keras.preprocessing.image.img_to_array(image)
        img = Image.open(image_path).convert('RGB')
        img = img.resize((300, 300 * img.size[1] // img.size[0]), Image.Resampling.LANCZOS)
        inp_numpy = np.array(img)[None]
        image_array = tf.constant(inp_numpy, dtype='float32')
        val_images.append(image_array)
        val_labels.append(class_index)

train_images = np.array(train_images)
train_labels = np.array(train_labels)
val_images = np.array(val_images)
val_labels = np.array(val_labels)

# Konversi dataset train menjadi tf.constant
# train_images = tf.constant(train_images, dtype=tf.float32)
# train_labels = tf.constant(train_labels, dtype=tf.int32)
# val_images = tf.constant(val_images, dtype=tf.float32)
# val_labels = tf.constant(val_labels, dtype=tf.int32)
train_images = tf.constant(np.squeeze(train_images), dtype=tf.float32)
train_labels = tf.constant(train_labels, dtype=tf.int32)
val_images = tf.constant(np.squeeze(val_images), dtype=tf.float32)
val_labels = tf.constant(val_labels, dtype=tf.int32)

# %%
print(train_images[0])
# Out:
# tf.Tensor(
# [[[207. 205. 206.]
#   [207. 205. 206.]
#   [208. 206. 207.]
#   ...
#   [223. 221. 221.]
#   [219. 218. 216.]
#   [219. 218. 216.]]
#
#  [[210. 208. 209.]
#   [211. 209. 210.]
#   [211. 209. 210.]
#   ...
#   [221. 220. 220.]
#   [219. 218. 216.]
#   [218. 217. 215.]]
#
#  [[212. 210. 211.]
#   [212. 210. 211.]
#   [212. 210. 211.]
#   ...
#   [220. 218. 217.]
#   [220. 217. 216.]
#   [219. 216. 215.]]
#
#  ...
#
#  [[220. 218. 219.]
#   [220. 218. 219.]
#   [220. 218. 219.]
#   ...
#   [222. 218. 217.]
#   [223. 219. 218.]
#   [222. 218. 217.]]
#
#  [[220. 218. 219.]
#   [221. 219. 220.]
#   [221. 219. 220.]
#   ...
#   [222. 218. 217.]
#   [222. 218. 217.]
#   [222. 218. 217.]]
#
#  [[219. 217. 218.]
#   [220. 218. 219.]
#   [220. 218. 219.]
#   ...
#   [221. 217. 216.]
#   [222. 218. 217.]
#   [222. 218. 217.]]], shape=(150, 300, 3), dtype=float32)

# %%
# Buat model untuk melatih data
EfficientNet = EfficientNetB0(
        include_top=False,
        weights='imagenet',
        input_shape=(150, 300, 3),
)

for layer in EfficientNet.layers:
    layer.trainable = False


x = tf.keras.layers.Flatten()(EfficientNet.output)
# x = tf.keras.layers.Dense(64, activation='relu')(x)
# x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(4, activation='softmax')(x)

model = Model(EfficientNet.input, x)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 300, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 150, 300, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 150, 300, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 150, 300, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 151, 301, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 75, 150, 32)  864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 75, 150, 32)  128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 75, 150, 32)  0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 75, 150, 32)  288        ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 75, 150, 32)  128        ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 75, 150, 32)  0          ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 75, 150, 32)  0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 75, 150, 16)  512         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 75, 150, 16)  64         ['block1a_project_conv[0][0]']
#  lization)
#
#  block2a_expand_conv (Conv2D)   (None, 75, 150, 96)  1536        ['block1a_project_bn[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 75, 150, 96)  384        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 75, 150, 96)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 77, 151, 96)  0          ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 38, 75, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 38, 75, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 38, 75, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 38, 75, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 38, 75, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 38, 75, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 38, 75, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 38, 75, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 38, 75, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 38, 75, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 38, 75, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 38, 75, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 38, 75, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 38, 75, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 38, 75, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 38, 75, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 38, 75, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 38, 75, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 38, 75, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 38, 75, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 41, 79, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 19, 38, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 19, 38, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 19, 38, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 19, 38, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 19, 38, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 19, 38, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 19, 38, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 19, 38, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 19, 38, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 19, 38, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 19, 38, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 19, 38, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 19, 38, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 19, 38, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 19, 38, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 19, 38, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 19, 38, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 19, 38, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 19, 38, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 19, 38, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 21, 39, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 10, 19, 240)  2160       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 10, 19, 240)  960        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 10, 19, 240)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 10, 19, 240)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 10, 19, 80)   19200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 10, 19, 80)  320         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 10, 19, 480)  38400       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 10, 19, 480)  1920       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 10, 19, 480)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 10, 19, 480)  4320       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 10, 19, 480)  1920       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 10, 19, 480)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 10, 19, 480)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 10, 19, 80)   38400       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 10, 19, 80)  320         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 10, 19, 80)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 10, 19, 80)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 10, 19, 480)  38400       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 10, 19, 480)  1920       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 10, 19, 480)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 10, 19, 480)  4320       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 10, 19, 480)  1920       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 10, 19, 480)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 10, 19, 480)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 10, 19, 80)   38400       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 10, 19, 80)  320         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 10, 19, 80)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 10, 19, 80)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 10, 19, 480)  38400       ['block4c_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 10, 19, 480)  1920       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 10, 19, 480)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 10, 19, 480)  12000      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 10, 19, 480)  1920       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 10, 19, 480)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 10, 19, 480)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 10, 19, 112)  53760       ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 10, 19, 112)  448        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 10, 19, 672)  75264       ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 10, 19, 672)  2688       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 10, 19, 672)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv (DepthwiseConv2  (None, 10, 19, 672)  16800      ['block5b_expand_activation[0][0]
#  D)                                                              ']
#
#  block5b_bn (BatchNormalization  (None, 10, 19, 672)  2688       ['block5b_dwconv[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 10, 19, 672)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 10, 19, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 10, 19, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 10, 19, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 10, 19, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 10, 19, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, 10, 19, 672)  75264       ['block5b_add[0][0]']
#
#  block5c_expand_bn (BatchNormal  (None, 10, 19, 672)  2688       ['block5c_expand_conv[0][0]']
#  ization)
#
#  block5c_expand_activation (Act  (None, 10, 19, 672)  0          ['block5c_expand_bn[0][0]']
#  ivation)
#
#  block5c_dwconv (DepthwiseConv2  (None, 10, 19, 672)  16800      ['block5c_expand_activation[0][0]
#  D)                                                              ']
#
#  block5c_bn (BatchNormalization  (None, 10, 19, 672)  2688       ['block5c_dwconv[0][0]']
#  )
#
#  block5c_activation (Activation  (None, 10, 19, 672)  0          ['block5c_bn[0][0]']
#  )
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, 10, 19, 672)  0           ['block5c_activation[0][0]',
#                                                                   'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, 10, 19, 112)  75264       ['block5c_se_excite[0][0]']
#
#  block5c_project_bn (BatchNorma  (None, 10, 19, 112)  448        ['block5c_project_conv[0][0]']
#  lization)
#
#  block5c_drop (Dropout)         (None, 10, 19, 112)  0           ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)              (None, 10, 19, 112)  0           ['block5c_drop[0][0]',
#                                                                   'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 10, 19, 672)  75264       ['block5c_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 10, 19, 672)  2688       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 10, 19, 672)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  block6a_dwconv_pad (ZeroPaddin  (None, 13, 23, 672)  0          ['block6a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block6a_dwconv (DepthwiseConv2  (None, 5, 10, 672)  16800       ['block6a_dwconv_pad[0][0]']
#  D)
#
#  block6a_bn (BatchNormalization  (None, 5, 10, 672)  2688        ['block6a_dwconv[0][0]']
#  )
#
#  block6a_activation (Activation  (None, 5, 10, 672)  0           ['block6a_bn[0][0]']
#  )
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
#
#  block6a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multiply)   (None, 5, 10, 672)   0           ['block6a_activation[0][0]',
#                                                                   'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv2D)  (None, 5, 10, 192)   129024      ['block6a_se_excite[0][0]']
#
#  block6a_project_bn (BatchNorma  (None, 5, 10, 192)  768         ['block6a_project_conv[0][0]']
#  lization)
#
#  block6b_expand_conv (Conv2D)   (None, 5, 10, 1152)  221184      ['block6a_project_bn[0][0]']
#
#  block6b_expand_bn (BatchNormal  (None, 5, 10, 1152)  4608       ['block6b_expand_conv[0][0]']
#  ization)
#
#  block6b_expand_activation (Act  (None, 5, 10, 1152)  0          ['block6b_expand_bn[0][0]']
#  ivation)
#
#  block6b_dwconv (DepthwiseConv2  (None, 5, 10, 1152)  28800      ['block6b_expand_activation[0][0]
#  D)                                                              ']
#
#  block6b_bn (BatchNormalization  (None, 5, 10, 1152)  4608       ['block6b_dwconv[0][0]']
#  )
#
#  block6b_activation (Activation  (None, 5, 10, 1152)  0          ['block6b_bn[0][0]']
#  )
#
#  block6b_se_squeeze (GlobalAver  (None, 1152)        0           ['block6b_activation[0][0]']
#  agePooling2D)
#
#  block6b_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6b_se_squeeze[0][0]']
#
#  block6b_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multiply)   (None, 5, 10, 1152)  0           ['block6b_activation[0][0]',
#                                                                   'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv2D)  (None, 5, 10, 192)   221184      ['block6b_se_excite[0][0]']
#
#  block6b_project_bn (BatchNorma  (None, 5, 10, 192)  768         ['block6b_project_conv[0][0]']
#  lization)
#
#  block6b_drop (Dropout)         (None, 5, 10, 192)   0           ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)              (None, 5, 10, 192)   0           ['block6b_drop[0][0]',
#                                                                   'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, 5, 10, 1152)  221184      ['block6b_add[0][0]']
#
#  block6c_expand_bn (BatchNormal  (None, 5, 10, 1152)  4608       ['block6c_expand_conv[0][0]']
#  ization)
#
#  block6c_expand_activation (Act  (None, 5, 10, 1152)  0          ['block6c_expand_bn[0][0]']
#  ivation)
#
#  block6c_dwconv (DepthwiseConv2  (None, 5, 10, 1152)  28800      ['block6c_expand_activation[0][0]
#  D)                                                              ']
#
#  block6c_bn (BatchNormalization  (None, 5, 10, 1152)  4608       ['block6c_dwconv[0][0]']
#  )
#
#  block6c_activation (Activation  (None, 5, 10, 1152)  0          ['block6c_bn[0][0]']
#  )
#
#  block6c_se_squeeze (GlobalAver  (None, 1152)        0           ['block6c_activation[0][0]']
#  agePooling2D)
#
#  block6c_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6c_se_squeeze[0][0]']
#
#  block6c_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multiply)   (None, 5, 10, 1152)  0           ['block6c_activation[0][0]',
#                                                                   'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv2D)  (None, 5, 10, 192)   221184      ['block6c_se_excite[0][0]']
#
#  block6c_project_bn (BatchNorma  (None, 5, 10, 192)  768         ['block6c_project_conv[0][0]']
#  lization)
#
#  block6c_drop (Dropout)         (None, 5, 10, 192)   0           ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)              (None, 5, 10, 192)   0           ['block6c_drop[0][0]',
#                                                                   'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2D)   (None, 5, 10, 1152)  221184      ['block6c_add[0][0]']
#
#  block6d_expand_bn (BatchNormal  (None, 5, 10, 1152)  4608       ['block6d_expand_conv[0][0]']
#  ization)
#
#  block6d_expand_activation (Act  (None, 5, 10, 1152)  0          ['block6d_expand_bn[0][0]']
#  ivation)
#
#  block6d_dwconv (DepthwiseConv2  (None, 5, 10, 1152)  28800      ['block6d_expand_activation[0][0]
#  D)                                                              ']
#
#  block6d_bn (BatchNormalization  (None, 5, 10, 1152)  4608       ['block6d_dwconv[0][0]']
#  )
#
#  block6d_activation (Activation  (None, 5, 10, 1152)  0          ['block6d_bn[0][0]']
#  )
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 5, 10, 1152)  0           ['block6d_activation[0][0]',
#                                                                   'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 5, 10, 192)   221184      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 5, 10, 192)  768         ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 5, 10, 192)   0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 5, 10, 192)   0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 5, 10, 1152)  221184      ['block6d_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 5, 10, 1152)  4608       ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 5, 10, 1152)  0          ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 5, 10, 1152)  10368      ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 5, 10, 1152)  4608       ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 5, 10, 1152)  0          ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 5, 10, 1152)  0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 5, 10, 320)   368640      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 5, 10, 320)  1280        ['block7a_project_conv[0][0]']
#  lization)
#
#  top_conv (Conv2D)              (None, 5, 10, 1280)  409600      ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization)    (None, 5, 10, 1280)  5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 5, 10, 1280)  0           ['top_bn[0][0]']
#
#  flatten (Flatten)              (None, 64000)        0           ['top_activation[0][0]']
#
#  dense (Dense)                  (None, 4)            256004      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 4,305,575
# Trainable params: 256,004
# Non-trainable params: 4,049,571
# __________________________________________________________________________________________________

# %%
history = model.fit(train_images,
                    train_labels,
                    epochs=25,
                    verbose=1,
                    validation_data=(val_images, val_labels)
                   )
# Out:
# Epoch 1/25
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0104 - accuracy: 0.9992 - val_loss: 0.1359 - val_accuracy: 0.9625
# Epoch 2/25
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9625
# Epoch 3/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0121 - accuracy: 0.9984 - val_loss: 0.1924 - val_accuracy: 0.9425
# Epoch 4/25
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9525
# Epoch 5/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0082 - accuracy: 0.9984 - val_loss: 0.1456 - val_accuracy: 0.9550
# Epoch 6/25
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9600
# Epoch 7/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9525
# Epoch 8/25
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9525
# Epoch 9/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0083 - accuracy: 0.9992 - val_loss: 0.1266 - val_accuracy: 0.9600
# Epoch 10/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9550
# Epoch 11/25
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9575
# Epoch 12/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.9525
# Epoch 13/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9600
# Epoch 14/25
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9625
# Epoch 15/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.1464 - val_accuracy: 0.9550
# Epoch 16/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9600
# Epoch 17/25
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9675
# Epoch 18/25
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9575
# Epoch 19/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9600
# Epoch 20/25
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9625
# Epoch 21/25
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9475
# Epoch 22/25
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9575
# Epoch 23/25
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9625
# Epoch 24/25
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9650
# Epoch 25/25
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9675

# %%
model.evaluate(val_images, val_labels)
# Out:
# 13/13 [==============================] - 1s 57ms/step - loss: 0.1477 - accuracy: 0.9675
# [0.14773058891296387, 0.9674999713897705]

# %%
# Plot the training and validation accuracies for each epoch

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

#Train and Validation Accuracy
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

#Train and Validation Loss
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# Confusion Matrix Heatmap
# class_labels = sorted(os.listdir('/kaggle/input/coffee-leaf-diseases/train'))
predictions = model.predict(val_images)
predicted_labels = np.argmax(predictions, axis=1)
# true_labels = val_generator.classes
cm = confusion_matrix(val_labels, predicted_labels)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='.2f', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 13/13 [==============================] - 1s 53ms/step

# %%
prediksi = model.predict(val_images)
y_pred = np.argmax(prediksi, axis=1)
# y_true = val_generator.labels

print(classification_report(val_labels, y_pred))
# Out:
# 13/13 [==============================] - 1s 52ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96       128
#            1       0.98      0.98      0.98       116
#            2       1.00      1.00      1.00        96
#            3       0.86      0.98      0.91        60
#
#     accuracy                           0.97       400
#    macro avg       0.96      0.97      0.96       400
# weighted avg       0.97      0.97      0.97       400

# %%
# Save model dengan fromat HDF5
tf.saved_model.save(model, "/kaggle/working/Model")
my_model = tf.saved_model.load('/kaggle/working/Model')

# convert model ke TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(my_model)
tflite_model = converter.convert()

# save TFLite model
with open('Coffee_disease_EfficientNetB0.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
import zipfile
import os

# Nama folder yang ingin Anda download
folder_name = '/kaggle/working/Model'

# Nama file ZIP yang ingin Anda berikan pada file yang diunduh
zip_file_name = 'Model_EfficientNetB0.zip'

# Mengompres folder menjadi file ZIP
with zipfile.ZipFile(zip_file_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(folder_name):
        for file in files:
            file_path = os.path.join(root, file)
            zipf.write(file_path, arcname=os.path.relpath(file_path, folder_name))

# Mengunduh file ZIP
from IPython.display import FileLink
FileLink(zip_file_name)
# Out:
# /kaggle/working/Model_EfficientNetB0.zip
